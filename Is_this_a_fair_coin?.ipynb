# %%
import numpy as pn 
import scipy as sp
import matplotlib as plt
import math 
from random import *

# %%
N = 100
bias = 1.0

# %%
Z = 0.0
for r in range(1, N + 1):
    I = randrange(0, 2)
    if I == 1:
        Z += 1
        print 'head'
    else:
        print 'tail'
    print I 
    print Z
# Out:
# tail
# 0
# 0.0
# tail
# 0
# 0.0
# head
# 1
# 1.0
# head
# 1
# 2.0
# tail
# 0
# 2.0
# tail
# 0
# 2.0
# head
# 1
# 3.0
# head
# 1
# 4.0
# tail
# 0
# 4.0
# head
# 1
# 5.0
# head
# 1
# 6.0
# head
# 1
# 7.0
# head
# 1
# 8.0
# head
# 1
# 9.0
# tail
# 0
# 9.0
# head
# 1
# 10.0
# tail
# 0
# 10.0
# tail
# 0
# 10.0
# head
# 1
# 11.0
# head
# 1
# 12.0
# tail
# 0
# 12.0
# head
# 1
# 13.0
# tail
# 0
# 13.0
# tail
# 0
# 13.0
# head
# 1
# 14.0
# tail
# 0
# 14.0
# tail
# 0
# 14.0
# tail
# 0
# 14.0
# tail
# 0
# 14.0
# head
# 1
# 15.0
# tail
# 0
# 15.0
# head
# 1
# 16.0
# tail
# 0
# 16.0
# head
# 1
# 17.0
# head
# 1
# 18.0
# tail
# 0
# 18.0
# head
# 1
# 19.0
# head
# 1
# 20.0
# head
# 1
# 21.0
# head
# 1
# 22.0
# tail
# 0
# 22.0
# head
# 1
# 23.0
# tail
# 0
# 23.0
# head
# 1
# 24.0
# tail
# 0
# 24.0
# tail
# 0
# 24.0
# tail
# 0
# 24.0
# head
# 1
# 25.0
# tail
# 0
# 25.0
# head
# 1
# 26.0
# head
# 1
# 27.0
# tail
# 0
# 27.0
# tail
# 0
# 27.0
# head
# 1
# 28.0
# head
# 1
# 29.0
# head
# 1
# 30.0
# head
# ...

# %%
for H in range (0, 11):
    prob_data_given_H_and_I = (H**Z)*(10-H)**(N-Z)
    prob_H_given_data_and_I = prob_data_given_H_and_I * bias
    scatter (H, prob_data_given_H_and_I)

print H, prob_data_given_H_and_I
# Out:
# 10 0.0
