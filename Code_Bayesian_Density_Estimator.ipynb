# %%
import numpy as pn 
from scipy import *
import matplotlib as plt
import math 
from random import *

# %%
#1. Find d_0 
#2. Find d_0 for any given position
#3. Find d_0 for all positions

# %%
Z = np.random.random(100)*1000, np.random.random(100)*1000

#scatter(X, Y, s = 20)
title('$\mathrm{Neighbors}$', fontsize=25)
xlabel('$x$', fontsize = 25)
ylabel('$y$', fontsize = 25)
xlim([0, 1000])
ylim([0, 1000])

scatter(Z[0], Z[1], c= 'b')

# %%
r = sqrt(Z[0]**2 + Z[1]**2)  
rs = sorted(r)
d_k = []

for i in range (8):
    d_k.append(rs[i])
    dist = (rs[i+1]-rs[i])/2.
    #print N, d_k
    #scatter(X[i], Y[i], c = 'r', s = 40)
print d_k
# Out:
# [67.365595773662633, 135.01328951643521, 183.23617404489684, 238.22746287647382, 238.26735320992324, 309.10034557300935, 309.40077340795295, 325.83857701362297]

# %%
k = [1., 2., 3., 4., 5., 6., 7., 8.]
fig = Figure(figsize=(19,19))
#Prob_d_0 = []
float(Prob_d_0)
#d_0 = range(1, 500, 5)
for d_0 in range(1, 500, 8):
    for i in range(2):
        Prob_d_0 = prod( ( (2.*exp(-(d_k[i] / d_0)**2) ) / (d_0 * math.factorial(k[i] - 1.)) )  * (d_k[i] / d_0 )**((2.*k[i]) - 1.) )
    scatter(d_0/100., Prob_d_0/0.005, c = 'b')# Fix normalization
    xlim([0, 4])

for d_0 in range(1, 500, 5):
    for i in range(4):
        Prob_d_0  = prod( ( (2.*exp(-(d_k[i] / d_0)**2) ) / (d_0 * math.factorial(k[i] - 1.)) )  * (d_k[i] / d_0 )**((2.*k[i]) - 1.) )
        #print Prob_d_0
    scatter(d_0/100., Prob_d_0/0.00700114131707, c = 'g')
    xlim([0, 4])
    
for d_0 in range(1, 500, 5):
    for i in range(8):
        Prob_d_0  = prod( ( (2.*exp(-(d_k[i] / d_0)**2) ) / (d_0 * math.factorial(k[i] - 1.)) )  * (d_k[i] / d_0 )**((2.*k[i]) - 1.) )
    #print Prob_d_0
    scatter(d_0/100., Prob_d_0/0.00903419421833, c = 'r')
    xlim([0, 4])

# %%
for d_0 in range(100, 800, 8):
    Prob_d_0  = ( ( (2.*exp(-(410. / d_0)**2) ) / (d_0 * math.factorial(2. - 1.)) )  * (410. / d_0 )**((2.*2.) - 1.) )
    #print Prob_d_0
    scatter(400./d_0, Prob_d_0/0.00270559367566)

for d_0 in range(100, 800, 4):
    Prob_d_0  = ( ( (2.*exp(-(410. / d_0)**2) ) / (d_0 * math.factorial(4. - 1.)) )  * (410. / d_0 )**((2.*4.) - 1.) )
    #print Prob_d_0
    scatter(400./d_0, Prob_d_0/0.00390733629626, c='g')
    
for d_0 in range(100, 800, 2):
    Prob_d_0  = ( ( (2.*exp(-(410. / d_0)**2) ) / (d_0 * math.factorial(8. - 1.)) )  * (410. / d_0 )**((2.*8.) - 1.) )
    #print Prob_d_0
    scatter(400./d_0, Prob_d_0/0.00557429157334, s=20, c='r')
    axvline(2.,linewidth=2,color='r',linestyle="-")
    title('$\mathrm{Middle}$ $\mathrm{Plot}, Fig. 9$', fontsize= 25)
    xlabel('$d/d_{0}$', fontsize = 25)
    ylabel('$p(d_{k})$', fontsize = 25)
    ylim([0, 1.1])
    xlim([0, 4])
